# %% [markdown]
# # Create a Table
# ## PROJECT
#
# It’s time to build fluency in SQL manipulation. We’re going to practice creating tables in SQL so you can hone your skills and feel confident taking them to the real world.

# %% [markdown]
# ### THE IMPORTANCE OF DATA AND SQL BASICS
# ## Create a Table
# In this project, you will create your own `friends` table and add/delete data from it!
#
# The instructions provided are a general guideline. Feel free to add more columns, insert more data, and create more tables.
#
# If you get stuck during this project or would like to see an experienced developer work through it, click “Get Help“ to see a `project walkthrough video`.

# %% [markdown]
# If you get stuck during this project or would like to see an experienced developer work through the project, watch the following project walkthrough video.
#
# ### [Learn SQL: Create Table](https://www.youtube.com/watch?v=nwLV5Txc8jM&feature=emb_title)

# %% [markdown]
# ## Tasks
#
# 1. **Create a table named friends with three columns:**
#
#     - id that stores INTEGER
#     - name that stores TEXT
#     - birthday that stores DATE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Beneath your current code, add Jane Doe to `friends`
#
#   Her birthday is May 30th, 1990.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **3. Let’s make sure that Jane has been added to the database:**
# ```
# SELECT *
# FROM friends;
# ```
# Check for two things:
#
# - Is friends table created?
# - Is Jane Doe added to it?1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4. Let’s move on! <br>
# Add two of your friends to the table.**
#
# Insert an `id`, `name`, and `birthday` for each of them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Jane Doe just got married! Her new last name is “Smith”.<br>
#    Update her record in friends.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. Add a new column named email.<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. Update the email address for everyone in your table.<br>
# Jane Smith’s email is jane@codecademy.com.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. Wait, Jane Smith is not a real person.<br>
# Remove her from friends.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 9. Great job! Let’s take a look at the result one last time:
# ```
# SELECT *
# FROM friends;
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Final SQL Project code

# %% [markdown]
# 1.
# ```
# CREATE TABLE friends(
#   id INTEGER,
#   name TEXT
#   birthday DATE
# );
# ```
# 2.
# ```
# INSERT INTO friends (id, name, birthday)
# VALUES (1, 'Jane Doe', 'May 30 1990' );
# ```
# 3.
# ```
# SELECT *
# FROM friends;
# ```
#
# 4.
# ```
# INSERT INTO friends (id, name, birthday)
# VALUES (2, 'Anil Peter', 'April 22 1997' );
# /
# INSERT INTO friends (id, name, birthday)
# VALUES (2, 'Raju', July 26 1999 );
# ```
#
# 5.
# ```
# UPDATE friends
# SET name = 'Jane Smith'
# WHERE id = 1;
# ```
#
# 6.
# ```
# ALTER TABLE friends
# ADD COLUMN email TEXT;
# ```
#
# 7.
# ```
# UPDATE friends
# SET email = 'jane@codecademy.com'
# WHERE id = 1;
# /
# UPDATE friends
# SET email = 'anilkumar_t@apssdc.in'
# WHERE id = 2;
# /
# UPDATE friends
# SET email = 'johnsilvaraju7@gmail.com'
# WHERE id = 3;
# ```
# 8.
# ```
# DELETE FROM friends
# WHERE id = 1;
# ```
# 9.
# ```
# SELECT * FROM celebs;
# ```
